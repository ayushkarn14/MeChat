# %%
import re

def parse_whatsapp_chat(chat_file):
    chat_data = []
    pattern = r"(\d{2}/\d{2}/\d{2}, \d{1,2}:\d{2}\s?(?:AM|PM|am|pm)?) - (.*?): (.*)"
    
    with open(chat_file, 'r', encoding='utf-8') as file:
        lines = file.readlines()
    
    for line in lines:
        match = re.match(pattern, line)
        if match:
            timestamp = match.group(1)
            sender = match.group(2)
            message = match.group(3)
            chat_data.append({'timestamp': timestamp, 'sender': sender, 'message': message})
    
    return chat_data

# Example usage
chat_data = parse_whatsapp_chat("psyduck.txt")
print(chat_data[:5])
# Out:
# [{'timestamp': '07/03/24, 5:02\u202fpm', 'sender': 'Psyduck', 'message': 'Kiska kasam khate h Ayush Karn'}, {'timestamp': '07/03/24, 5:02\u202fpm', 'sender': 'Psyduck', 'message': 'Yash ka? Apna?'}, {'timestamp': '07/03/24, 5:02\u202fpm', 'sender': 'Ayush Karn', 'message': '<Media omitted>'}, {'timestamp': '07/03/24, 5:02\u202fpm', 'sender': 'Ayush Karn', 'message': 'Mummy ka'}, {'timestamp': '07/03/24, 5:05\u202fpm', 'sender': 'Ayush Karn', 'message': '?'}]

# %%
conversation_pairs = []
for i in range(1, len(chat_data)):
    if chat_data[i]['sender'] == "Ayush Karn":
        conversation_pairs.append((chat_data[i-1]['message'], chat_data[i]['message']))
conversation_pairs
# Out:
# [('Yash ka? Apna?', '<Media omitted>'),
#  ('<Media omitted>', 'Mummy ka'),
#  ('Mummy ka', '?'),
#  ('?', '?'),
#  ('?', 'Megha?'),
#  ('Jao Shanti se', 'Ok'),
#  ('Ok', '?'),
#  ('?', 'null'),
#  ('null', '?'),
#  ('?', 'Aaaooo'),
#  ('Aaaooo', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', 'null'),
#  ('null', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('?', 'Baat karo'),
#  ('Kyu', 'Pata nai'),
#  ('Pata nai', 'Nai man kr ra Jane ka'),
#  ('Nai man kr ra Jane ka',
#   'Ab bhi bharosa nai hai ki hata diye hai har jagha se?'),
#  ('Ha', 'Kaise dilaye?'),
#  ('Idk', 'Hum pura chat clear kr diye, media ke saath'),
#  ('Hum pura chat clear kr diye, media ke saath', 'Humko rakhna hota hai chat'),
#  ('Phone me kahi bhi daal sakta h', 'Phone format kr de?'),
#  ('Tum kaha kaha ja sakta ab hm soch bhi nai sakte', 'Mat bolo na ease'),
#  ('Mat bolo na ease', 'Itna time ka chat ura diye hum 😭'),
#  ('Itna time ka chat ura diye hum 😭',
#   'Mereko rakhna hota tha chat isiliye WhatsApp PE ane bolte the telegram pe nai'),
#  ('Mereko rakhna hota tha chat isiliye WhatsApp PE ane bolte the telegram pe nai',
#   'Kyoki waha TM bhi delete kr sakti hai'),
#  ('Kyu udaya phir', 'Tereko bharosa dilane ke liye'),
#  ('Todna he nai tha', 'Sorry'),
#  ('Vid hatana tha sirf', 'Hata diye the'),
#  ('Hata diye the', 'Please maaf kr do na'),
#  ('Please maaf kr do na', 'Megha?'),
#  ('Megha?', '?'),
#  ('Kuch bolna h ya jaye', 'Sorry'),
#  ('Sorry', 'Phone atak ra tha'),
#  ('Phone atak ra tha', 'null'),
#  ('?', 'Please maaf kr do na'),
#  ('Please maaf kr do na', 'Ya block karo'),
#  ('Ya block karo', '?'),
#  ('?', 'Megha'),
#  ('Megha', '?'),
#  ('Ye jante hue jo kiya h? Aur jabki hmko abhi bhi wiswas nai ki tum hata diya hoga',
#   'To block kr do'),
#  ('Assume karlo ki block h', 'Hum block kr re'),
#  ('Ofc', 'Jab unblock krne bolegi kr denge'),
#  ('Hm kyu bolenge', 'TM nai kr ri isliye hum kr re'),
#  ('TM nai kr ri isliye hum kr re', 'Bye'),
#  ('Bye', '.'),
#  ('.', '..'),
#  ('..', '.'),
#  ('null', 'null'),
#  ('Ye lo', '.'),
#  ('.', '.'),
#  ('.', '?'),
#  ('?', 'Dp kyo nai dikha ra'),
#  ('Bye', 'Kyooo'),
#  ('Kyooo', 'Nahi'),
#  ('Nahi', 'Are'),
#  ('Are', 'Switched off?'),
#  ('null', 'Nikal gye'),
#  ('Nikal gye', 'Aur pata nai kyo nai baj ra tha phone'),
#  ('Aur pata nai kyo nai baj ra tha phone', 'Kya'),
#  ('Kya', '?'),
#  ('Kuch nai', '<Media omitted>'),
#  ('How romantic', 'Awwwww'),
#  ('Awwwww', 'Thank you'),
#  ('Thank you', 'Kya'),
#  ('Kya', 'Kr'),
#  ('Kr', 'Rii'),
#  ('Rii', '??'),
#  ('??', '?'),
#  ('?', '?'),
#  ('?', '?'),
#  ('Nahi', 'Oo'),
#  ('Oo', 'Oo'),
#  ('Oo', 'Hi'),
#  ('Bye', '<Media omitted>'),
#  ('<Media omitted>', 'Kyo'),
#  ('Kyo', 'Kyo'),
#  ('Kyo', '<Media omitted>'),
#  ('Kya', 'Kyo nai bole?'),
#  ('Kyunki hm bolre', '😂'),
#  ('😂', 'But why'),
#  ('Bye', 'Kiske saath?'),
#  ('Kiske saath?', 'Dekh to re'),
#  ('Dekh to re', 'Yash aur Ayush Bisht'),
#  ('Yash aur Ayush Bisht', 'No'),
#  ('Hmko bhi kaam h', 'Kya'),
#  ('Hai', 'Kya'),
#  ('Bas hai', 'Kya hai'),
#  ('Kya hai', 'Breakup krne jari to batao'),
#  ('Reels dekhna', 'Hat'),
#  ('Hm jare aise bhi', 'Kyo'),
#  ('Kyo', 'Kr re baat'),
#  ('Kr re baat', 'Idhar hi hai'),
#  ('Zarurat nai', 'Are'),
#  ('Meresaath 2 kaam nai', 'Why'),
#  ('Why', 'Hum kr sakte hai'),
#  ('Date se aya h', 'Date nahi tha'),
#  ('Ik', 'To kr re'),
#  ('Mereko acceptable nai', '😒'),
#  ('Bye', 'Dere'),
#  ('Dere', 'Pura focus'),
#  ('Got band kardiya?', 'Nahi'),
#  ('Nahi', 'Wo dono bhi dekh ra'),
#  ('Wo dono bhi dekh ra', 'Band kaise kr de'),
#  ('Tum dekhra dekho', 'Are to hum hai naa'),
#  ('Hm jare', 'Force nai kr ri to kya'),
#  ('Force nai kr ri to kya', 'No'),
#  ('Hmko 2 kaam ke saath nahi rehna',
#   'Tumhara pati affair karega to usko bhi ye bolegi?'),
#  ('Puchna apni didi se wo kya bolegi', '😒'),
#  ('Aisa fuddu jaisa sawal laata kyu', 'Mera bolo na'),
#  ('Mera bolo na', 'Suno'),
#  ('Suno', 'Ye tumhara accha nahi lagta mereko'),
#  ('Aur mera pati tere jaisa gochu nai hoga',
#   'Didi mummy ka jab bolne lagti hai'),
#  ('Didi mummy ka jab bolne lagti hai', 'Humko maar nai karna ispe'),
#  ('Humko maar nai karna ispe', 'Bas bol dere'),
#  ('Isilye bolte h taaki waisa baat tum wapas nai laao', 'To mereko bolo na'),
#  ('Kyunki tera aisa wahiyat baat hmko bhi accha nai lagta',
#   'Ki apni wife se puchna'),
#  ('Tum bewakoof',
#   'Hum tumhari mummy ke baare me ya tumhari behen ke baare me kuch bhi bole hai Aaj Tak?'),
#  ('Hum tumhari mummy ke baare me ya tumhari behen ke baare me kuch bhi bole hai Aaj Tak?',
#   'Bol bhi nai sakte kabhi'),
#  ('Affair kahase aagaya', 'Mazak kiye'),
#  ('Mazak kiye', 'Mere ko bol sakti hai kuch bhi'),
#  ('Har aadmi tere jaisa ladkibaaz thodi', 'Hum larkibaz hai?🙄'),
#  ('OHH YES', 'Kon larki bhaw deti hai mere ko?🥹'),
#  ('Kon larki bhaw deti hai mere ko?🥹', 'Tumko chor ke'),
#  ('Deti nai h', 'Agar tumse baat karna larkibaazi hai, to hu mai larkibaaz'),
#  ('Hm to de dete kyunki hm pehle se jante h', 'Aaj Anuska puchi thi 😂'),
#  ('Kya', '<Media omitted>'),
#  ('<Media omitted>', 'Ooooo'),
#  ('Chala he jata', "Pehle se Domino's me the"),
#  ("Pehle se Domino's me the", 'Kha hi re the'),
#  ('Ek date pe tha already but', 'Ha ha'),
#  ('Kya baat hua isha se', 'Kya baat hua matlab'),
#  ('Kya baat hua matlab', 'Ease hi generally'),
#  ('Like', 'Mostly CUET ka'),
#  ('Mostly CUET ka', 'College ka'),
#  ('College ka', 'Normal baat hi'),
#  ('Kitna der tha saath', 'Kya hua kaise bataye'),
#  ('Kya hua kaise bataye', '1.75 hr'),
#  ('1.75 hr', 'Fir college aake Yash ko neeche bula liye'),
#  ('Fir college aake Yash ko neeche bula liye', 'Walk kiye 1 hr'),
#  ('Usko pata tha tumdono saath jara?', 'Ig yes'),
#  ('Ig yes', 'Batayi hi hogi'),
#  ('Batayi hi hogi', 'Wo'),
#  ('Wo', 'Hum jab nikle tab to soya tha ye'),
#  ('Isha pasand h tereko?', 'Nahii'),
#  ('Nahii', 'Kitna baar puchti hai'),
#  ('Jao got dekho', 'Dekh re'),
#  ('Dekh re', 'TM Raho'),
#  ('TM Raho', '?'),
#  ('?', '?'),
#  ('?', '?'),
#  ('?', '?'),
#  ('?', '?'),
#  ('?', '?'),
#  ('Dekhra to dekho', 'Baat kr re naaa'),
#  ('Dono nahi', 'Kyo'),
#  ('Kyo', 'Hello'),
#  ('Ye ans enough h mere khayal se', 'Are'),
#  ('Are', 'To hum baat kr re na'),
#  ('Nahi', 'Tmko reply nai karenge tab bolna'),
#  ('Attention ek jagah daalna seekho tum thoda', 'Are'),
#  ('Dekhra h to side me reel ya chat karte rehna zaruri nai',
#   'Tab hi pategi kya koi?'),
#  ('Wth', 'To'),
#  ('Idk about KOI .', 'Accha'),
#  ('Accha', 'To tmko attention denge to tm pat jayegi?'),
#  ('Ya merese baat kar ra to merese karna', 'Isiliye to nai dere na pura'),
#  ('Isiliye to nai dere na pura', 'Nai pata hai'),
#  ('Tumhare liye mereko patana aasan nai ab', 'Chahiye hi nai'),
#  ('Hoga bhi nai', 'Chahiye hi nahi na'),
#  ('Tumhare bata hua attention aur bare minimum sebhi kam me hm 1 mahina na tike ab. 4 saal to bahut tha',
#   'Oooo'),
#  ('Accha h ki tum apna limit janta h', 'Huh'),
#  ('Huh', 'Tm limit hai?'),
#  ('Tm limit hai?', 'हेलो'),
#  ('हेलो', 'Busy to tm lag ri'),
#  ('Hm to insta reels dekhne chal jare', 'Kyo'),
#  ('Kyo', 'Ek jagha do attention'),
#  ('Jaise ki tum dera', 'Ex hoke bol ri'),
#  ('Ex hoke bol ri', 'Hum baat to kr re'),
#  ('Ha isilye bolre', '<Media omitted>'),
#  ('Wahi to bole ki 4 saal bina bare minimum ke bhi kaat liye, tab yesab nai dikhta tha , ab dikhta h',
#   'Kyo'),
#  ('Kyo', 'Ab kyo dikh ra'),
#  ('Ik tereliye ye unfortunate hoga', 'Mere liye kyo unfortunate hoga'),
#  ('Tumse he realise hua', 'Accha baat hai'),
#  ('Accha baat hai', 'Kaisa chahiye ab pata hai'),
#  ('Kaisa chahiye ab pata hai', 'Bf hote hue'),
#  ('Ha hai he', 'To ye bf ko kab chor ri?'),
#  ('Jab wo boundry cross kar jayega', 'Kya hai boundary?'),
#  ('Bahut kuch h ek ek batane thodi baithenge',
#   'Kya pata easa kuch ho Jo abhi bhi na dikh ra ho'),
#  ('Kya pata easa kuch ho Jo abhi bhi na dikh ra ho',
#   'Isko chorne ke baad pata chale'),
#  ('Isko chorne ke baad pata chale', 'Fir bolegi ye kaise reh liya itna time'),
#  ('Fir bolegi ye kaise reh liya itna time', 'Isiliye pehle hi chor de'),
#  ('Ho sakta h', '.'),
#  ('Jare ab', 'When'),
#  ('When', 'No'),
#  ('Jab pura attention de sako to aana', 'Hai to dhyaan'),
#  ('Hai to dhyaan', 'Tumko bata diye ki dekh re isliye bol ri'),
#  ('Tumko bata diye ki dekh re isliye bol ri', 'Nai to pata chalta kya'),
#  ('Tum hmesha he ye karta h', 'Tumko mera attention chahiye?🥹'),
#  ('Nai', 'To'),
#  ('Jab baat kar ra ho to attention sara yaha chahiye', 'Ab isi pe baat hoga?'),
#  ('Ab isi pe baat hoga?', 'Ki attention dere ya nai'),
#  ('Tum apna harkat theek karo', 'Padh ri to kya bol sakte hai ab'),
#  ('Padh ri to kya bol sakte hai ab', 'Jao'),
#  ('Reels aadmi dekhta h taaki bore na ho.',
#   'Are fir tm pat jayegi theek karenge to'),
#  ('Are fir tm pat jayegi theek karenge to', 'Isiliye to nai kr re'),
#  ('Isiliye to nai kr re', '😂😂😂'),
#  ('😂😂😂', 'GOT dekh re coz khatam karna hai jaldi'),
#  ('GOT dekh re coz khatam karna hai jaldi',
#   'Isiliye din bhar chalte rehta hai'),
#  ('Isiliye din bhar chalte rehta hai', 'Din me dekhte dekhte soo gye the'),
#  ('Tere SIRF ATTENTION DENE se hm nahi pat re',
#   'Are to isiliye nai theek kr re hai na'),
#  ('Are to isiliye nai theek kr re hai na', 'Aadat'),
#  ('Aadat', 'Apna'),
#  ('Apna', 'Then'),
#  ('Mereko patane ke liye bahut kuch lagta h ', '<Media omitted>'),
#  ('Isiliye bole', 'Tmse dur rahe fir?'),
#  ('Ghanta samajh aya kuch', 'Oh'),
#  ('Oh', 'Wo boobs hai'),
#  ('Kon', 'Jail me larki hai, nude'),
#  ('Jail me larki hai, nude', 'Pura dikhaya lekin paar ho Gaya'),
#  ('Pura dikhaya lekin paar ho Gaya', '?'),
#  ('Pura?', 'Ha'),
#  ('Neeche bhi?', 'Abhi nai'),
#  ('Abhi nai', 'Lekin isme neeche bhi dikha deta hai'),
#  ('Dikhata h?????', 'Ha'),
#  ('Woah', 'Brothels ka scenes me'),
#  ('Brothels ka scenes me', 'Pura'),
#  ('..', 'And hum train me dekhte hue aare the😂😂'),
#  ('Ab aya samajh', 'Agar ye sab scenes nai hota to bahut famous hota'),
#  ('ISILYE BHI*', 'Hai to ab sabko recomend nai kr sakte'),
#  ('Hai to ab sabko recomend nai kr sakte', 'Meri didi mere ko nai batayi'),
#  ('Meri didi mere ko nai batayi', 'Nai to bolti dekhne'),
#  ('Nai to bolti dekhne', 'To bahut pehle dekh chuke hote'),
#  ('Ok', '?'),
#  ('Kisliye', 'Tmko to patana hai na'),
#  ('Tmko to patana hai na',
#   'Dusari koi pate to uske liye bhi ye criteria hua ki baki larki se baat na kare'),
#  ('Hmko patana h to hmse dur rahega', 'To tmse nai kr payenge na baat'),
#  ('To tmse nai kr payenge na baat', 'Tereko kyo patana hai'),
#  ('Tereko kyo patana hai', 'Tera jaane taaki dusara pe use kr sake'),
#  ('Wahi to puche', 'Tm to single hi nai hai'),
#  ('Jiske liye karna hota h aadmi khudse karta h', 'Oh'),
#  ('Oh', 'Abhi to decided hi nai hai kisko patana hai'),
#  ('Abhi to decided hi nai hai kisko patana hai', 'Koi hai hi nai'),
#  ('Koi hai hi nai', 'To abhi to kr hi sakte hai na sabse baat'),
#  ('Nahi karna to mat karo', 'Sahi baat'),
#  ('Sahi baat', 'Uska bhi to hua'),
#  ('Nai', 'Kyo'),
#  ('Kyo', 'हेलो'),
#  ('हेलो', 'Net Gaya kya mera'),
#  ('Net Gaya kya mera', 'Oh ha'),
#  ('Bas rok ke rakha ',
#   'Samjhe, ab to iske liye term hai....larki sab bhi krti hai, breadcrumbing'),
#  ('Samjhe, ab to iske liye term hai....larki sab bhi krti hai, breadcrumbing',
#   'Ab ye batao'),
#  ('Eg lelo', 'Tm current bf ko permanent hoga wo maanti hai?'),
#  ('Tm current bf ko permanent hoga wo maanti hai?', 'Sabkuch deti hai?'),
#  ('Sabkuch bole to', 'Means usko permanent manna'),
#  ('Ha yahi Kiya meresaath bhi 4 saal', 'Hat'),
#  ('Hat', 'Tm bhi wahi kr ri tab?'),
#  ('Tm bhi wahi kr ri tab?', 'Abhi'),
#  ('Lesson mil Jane ke baad se same galti thodi karenge', 'Are'),
#  ('Are', 'Ye kya baat hua'),
#  ('Ye kya baat hua', 'Means ab TM wo kaam kr ri'),
#  ('Kon kaam', 'Breadcrumbing🙄'),
#  ('Antar h', 'Timepass?'),
#  ('Timepass?', 'Choose'),
#  ('.', 'POLL:'),
#  ('POLL:', 'Vote karo'),
#  ('Vote karo', 'Iska ss bhejna hai usko'),
#  ('Koi nai h inme se', 'Then'),
#  ('Then kuch nai', 'Batao apne se'),
#  ('Batao apne se', 'Bf nai hai?'),
#  ('Ans', 'Nahi chorenge'),
#  ('Nahi chorenge', 'Dono me'),
#  ('Kya dono me', 'Dono question ka ans'),
#  ('Aur samne wali ka time waste', 'Larki sab bhi krti hai'),
#  ('Larki sab bhi krti hai', 'Ha to theek hai'),
#  ('Ha to theek hai', 'Ispe baat thodi kr re ki baki sab kya krta hai'),
#  ('Kyunki hm sune h kitna married couple ka reel se', 'Tm kya kr ri batao'),
#  ('Isilye to kisiko 10 saal rakh ke bhi bare minimum nai diya',
#   'Mereko kab milegi then'),
#  ('Idk', 'Is info ka hum kya kare'),
#  ('Is info ka hum kya kare', ','),
#  ('Tere options mese kuch nai', 'To apne se bata do'),
#  ('Kuch nai h', 'Kya'),
#  ('Kya', 'Bf nahi hai?'),
#  ('Tere time aisa  kuch hota to kabka nikal diye hote tereko bhi',
#   'Means Maan ri hai na permanent'),
#  ('NAHI', 'Ab kuch dikkat hone pe breakup to ho hi sakta hai'),
#  ('Permanent kisiko nai maanre', 'Lekin sab sahi chala to hai na permanent'),
#  ('Jyotirmay se mera kl shaadi to h nai', 'Means Raha to'),
#  ('But I wish you all the best', 'Abhi tak 2 me se 1 bhi nai hua hai?'),
#  ('Hmko aadha baat samajh he nai aara', '2 baar bolegi na usko'),
#  ('2 baar bolegi na usko', "Then you're out"),
#  ("Then you're out", 'To 2 me se 1 baar bhi nai hua hai abhi Tak?'),
#  ('Tum bas bak ra', 'Hat'),
#  ('Hat', '.'),
#  ('Kon baat', '2 baar theek karegi boli naaa'),
#  ('2 baar theek karegi boli naaa', 'Usko'),
#  ("Jaise ye baat usko pata h ki wo issue ko solve karne me delay karega ya wo pretend karega ki sab normal h to he's fucked.",
#   'Ye batao na, TM boli na 2 baar theek karegi usko'),
#  ('Sudhar gaya to well and good', "Then you're out"),
#  ('Ha', 'To 2 me se kitna baar batayi hai abhi tak?'),
#  ('To 2 me se kitna baar batayi hai abhi tak?', '0?'),
#  ('Hmko yaad nai ara aisa kuchh jo kiya na ho', 'Tab to shadi hora'),
#  ('Tab to shadi hora', 'Abhi Tak agar 0 hai'),
#  ('Aajana phir', 'Okay'),
#  ('Okay', 'Khane to ofc ayenge'),
#  ('Bolta aise h jaisr kl hora', 'Non veg rakhna'),
#  ('Idk', 'Bata re'),
#  ('Bata re', 'Rakhna'),
#  ('Tereko hm ek baar 10 baar batate the tum nai sunta tha',
#   'Are to ab merese kya'),
#  ('Ye sun leta h max baat ek baarme', '🤦🏻\u200d♂'),
#  ('Sab apna he dekhta h na', 'Tera life Megha ka Swayamvar hai?'),
#  ('Tf', 'Waisa hi lag ra sun ke'),
#  ('Nai to hm koi bhi se shaadi karle?', 'Nahi'),
#  ('Wahi to hm bole?', 'But itna kyo sochna hai ispe'),
#  ('But itna kyo sochna hai ispe', 'Mast single raho'),
#  ('Momos khana h mereko',
#   'Hum to breakup krne isliye bol re taaki kuch time to single raho'),
#  ('Hm sochre??? Wtf', 'Kiya'),
#  ('TUM PUCHRA?????', 'Ye kaha se aa gaya'),
#  ('Hm nai sochte', 'Relationship me hai na'),
#  ('Hm to bf ka bhi nai sochte', 'Then let him goo'),
#  ('Breakup hona hoga hojayega', 'Kr le bol re'),
#  ('Abhi kabse baat band h', 'Okay'),
#  ('Tum ladka sahi nai tha ', 'Bhagwan thodi liye kuch'),
#  ('Bhagwan thodi liye kuch', '*kiye'),
#  ('*kiye', 'Larka sahi nai tha?😒'),
#  ('Jab hua tha na tab hmko lagta tha ki kyu hua , hm sab theek kar dete, nai hona chahiye tha',
#   'Ha'),
#  ('Yes', 'Ek 2 breakup to sabka hona chahiye'),
#  ('Ek 2 breakup to sabka hona chahiye', 'Tera at least 2'),
#  ('MERE BAAHON ME NAHI BAITHA HUA H WO ABHI', 'Set him free'),
#  ('Set him free', 'Chal tereko kl momo khila denge'),
#  ('Kya bolra', 'Breakup kr lo kl'),
#  ('Breakup kr lo kl', 'Deal?'),
#  ('Kuchbhi bolta h', 'Kyaa'),
#  ('Kyaa', 'Bolo'),
#  ('Bolo', 'Order kr denge'),
#  ('Momos ke liye kon breakup karta h', 'Momo accha nai lagta?'),
#  ('Terese prhle se pasand h', 'To'),
#  ('To', 'Lelo deal'),
#  ('Lelo deal', 'Waiting'),
#  ('Waiting', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('Relationship advice to hm tumse nai he lena chahenge ATLEAST',
#   'Advice thodi dere'),
#  ('Advice thodi dere', 'Offer dere'),
#  ('Offer dere', 'Momos ka'),
#  ('Kam h', 'Then'),
#  ('Band karega ye?', 'Batao kya chahiye 😂'),
#  ('10k😂', 'Installments me chalega?'),
#  ('Are you serious??😂', 'Negotiate karenge'),
#  ('Negotiate karenge',
#   'Iske baad jitna baar khane jayenge saath me tumko pay karna hai'),
#  ('Kya mtlb', 'Means hum nai pay karenge kabhi bhi'),
#  ('Kya nai pay karega', 'Koi bhi chiz me'),
#  ('Koi bhi chiz me', 'Khane me, kuch khareedne me'),
#  ('Khane me, kuch khareedne me', 'Auto me'),
#  ('Auto me', 'Agar tere saath jayenge kabhi tab'),
#  ('Isse kya hoga', 'Paisa bachega'),
#  ('Paisa bachega', 'Mera'),
#  ('And', 'Abhi ka 10k balance krne ke liye'),
#  ('Abhi ka 10k balance krne ke liye', 'Kuch nai'),
#  ('Tum breakup ke peeche haath dho ke kyu pada h', 'Ease hi'),
#  ('Ease hi', 'Single nai Rahi tm'),
#  ('Single nai Rahi tm', 'Shanti se single raho kuch time'),
#  ('Tumse dekha nai jara ki tum single h aur hm relationship me?', 'Nahii'),
#  ('Tumko mereko single karke wapas mere naak me dum karna h?',
#   'Apne bol ri ki larki log ka attention lera'),
#  ('Apne bol ri ki larki log ka attention lera', 'Naak me dam?'),
#  ('Leta he h', 'To Terese kya'),
#  ('To Terese kya', 'Dekho'),
#  ('Merese kya', 'Ek ke saath kha re, dusari bula ri🥹'),
#  ('Bye', 'No'),
#  ('No', 'Why'),
#  ('Bye', 'Ha?'),
#  ('Ha?', 'AA jayegi?'),
#  ('AA jayegi?', 'To deal leri?'),
#  ('Konsa', '10k'),
#  ('10k', 'Breakup'),
#  ('Breakup', 'And har jagha tm pay karegi'),
#  ('Khud dinbhar ladkibaazi karo aur mera breakup karana h', 'Idk'),
#  ('Idk', 'Bheje to the 2'),
#  ('Bhagta h ki ek laat maare', 'Relationship me nai hai na'),
#  ('Relationship me nai hai na', 'Tab kyo na kare'),
#  ("Ladki ka I'd number lete rehna h", 'Kisi ko gf thodi bana re'),
#  ('Ha to tum jo kar ra hm rokre?', 'Na'),
#  ('IDK???', 'Bata re'),
#  ('Kya karta h udhar idk', 'Ha anuska bannerjee ko patana hai🥹'),
#  ('Ha anuska bannerjee ko patana hai🥹', 'Uske saath fir Ben 10 khelenge'),
#  ('Best h tereliye', 'Bolenge cannon bolt, rollout'),
#  ('Tum kya banega', '😂😂'),
#  ('Motu Patlu ki Jodi', '🙄'),
#  ('🙄', '.'),
#  ('.', '.'),
#  ('Yes', 'Sahi hai na anuska?'),
#  ('Sahi hai na anuska?', 'Yaar hum kl se baahar jayenge'),
#  ('Yaar hum kl se baahar jayenge',
#   'Room me rahe rahe dimag kharab ho jata hai'),
#  ('Room me rahe rahe dimag kharab ho jata hai', 'Daurna hai thoda'),
#  ('Ye soke uthi thi', '<Media omitted>'),
#  ('Phone kharab', 'Ha'),
#  ('ARE PERFECT H', 'Sahi hi hai'),
#  ('Sahi hi hai', 'Baal'),
#  ('Baal', 'Okay'),
#  ('Ik', 'Lekin lambaaa'),
#  ('😂', 'Karoo'),
#  ('Taante h klse', 'Kya chiz me?'),
#  ('Dikhe to dikhao', 'Humko kaha se dikhega'),
#  ('Kata to h', 'Lamba better hai'),
#  ('Ugg jayega wapas i hope', 'Katana hi kyo tha'),
#  ('Katana hi kyo tha', 'Sahi to thaa'),
#  ('Sahi to thaa', 'Ye Jyoti ke chakkar me kata li'),
#  ('Usko to PATA BHI NAI KI YESAB HUA H', 'Lekin current bf wahi hai na'),
#  ('Lekin current bf wahi hai na', 'Basss'),
#  ('Hmko khud lamba baal pasand h', 'Toooo???'),
#  ('To neeche se rough hogaya tha', 'Koi dusara shampoo?'),
#  ('Hmko achanak se ye idea kahase aaya MAALUM?', 'Ha thick is better'),
#  ('Hmko bhi karana tha', 'Yt Kam dekho to'),
#  ('Phir soche ki baal uga he nai to', 'Lamba baal is better'),
#  ('KAHA BUSY H', 'Ruko'),
#  ('Ruko', 'Aare'),
#  ('Kahase', 'Ha'),
#  ('Ha', 'Bisht gaya'),
#  ('Bisht gaya', 'Yash sora'),
#  ('Yash sora', 'Earphones laga liye'),
#  ('Earphones laga liye', 'Ha thick to mereko bhi accha lagta hai'),
#  ('Ha thick to mereko bhi accha lagta hai', '😌'),
#  ('😌', '.'),
#  ('Ok', 'Aur ab ye batao'),
#  ('Uf', 'Tm merese isiliye baat kr ri coz Jyoti nai kr ra🥹'),
#  ('Jyotirmay se hm nai kar re', 'Ha wahi'),
#  ('Ha wahi', 'Isiliye merese kr ri'),
#  ('Hm tumse kar re kyunki mera man',
#   'Coz wo rehta hai tab to tm busy rehti hai'),
#  ('Nope', 'Attention 2 jagha deke'),
#  ('Hm aise bhi rehte h', 'Oooo'),
#  ('Hmko padhne jana tha', 'Are bole to padhne Jana hai to kya bol sakte hai'),
#  ('Are bole to padhne Jana hai to kya bol sakte hai', 'Padhna hai to jao'),
#  ('Padhna hai to jao', 'Reels dekhne nai'),
#  ('Reels dekhne nai', '.'),
#  ('.', '.'),
#  ('Ha phir to rok liya bekar sawal me', 'TM ruki'),
#  ('TM ruki', 'Jaao padhna hai to'),
#  ('Ab soyenge', 'Audio nai hai?'),
#  ('Audio nai hai?', 'Nice'),
#  ('Kuch khaas bole he nai to hata diye', 'Ok'),
#  ('Dekho', 'Idk'),
#  ('Idk', 'Dekh re'),
#  ('Dekh re', 'Login nai horq'),
#  ('..', 'Nai hora'),
#  ('Nai hora', 'Tumko SMS me kya aya?'),
#  ('<Media omitted>', 'Then Monday'),
#  ('Then Monday', 'Coz Sunday ko ata nai hai'),
#  ('Nykka bolta h Sunday lekin hmesha ek din pehle bhejta',
#   'Sunday ko nai ata hai kuch'),
#  ('Are hmesha', 'Sat Aya nai, then ab Mon hi'),
#  ('Sat Aya nai, then ab Mon hi', 'Lekin chutti hota hai Sunday ko'),
#  ('Ek din pehle aata', 'Ayega nai kabhi kuch'),
#  ('Ok', 'Ha to sat na'),
#  ('Karn', 'Ha'),
#  ('Ha', 'Ease kyo bol ri'),
#  ('Bolo', 'Ha'),
#  ('Kya', 'Kya matlab 😑'),
#  ('Kya matlab 😑',
#   'Dosti nai torenge wala baat tm bekar aadmi hai ik se kaise start kr sakti hai'),
#  ('Dosti nai torenge wala baat tm bekar aadmi hai ik se kaise start kr sakti hai',
#   'Dosti nai tor re'),
#  ('KISSE', 'Jab Tak Tera pati ya meri wife ko dikkat na ho🤷🏻\u200d♂️'),
#  ('Jab Tak Tera pati ya meri wife ko dikkat na ho🤷🏻\u200d♂️', 'Terese'),
#  ('Boki h kya', 'Are'),
#  ('Are', 'TM wife hogi to chalta tumko koi ladki acchi dost ho?'),
#  ('TM wife hogi to chalta tumko koi ladki acchi dost ho?', 'Wife choro'),
#  ('Ofc', 'Gf'),
#  ('😂', 'Jab thi tab bhi itna isha krittika ke liye krti thi'),
#  ('TUM MERA BADA SUNA JAISE', 'Ki dinner ke baad saath hai'),
#  ('KISISE KAM NAI KIYA KABHI', 'Kam to kiye the'),
#  ('Kam to kiye the', 'Band nai'),
#  ('NAHI', 'Ha to ab bhi wahi socho'),
#  ('Ha to kyu nai kiya', 'Koi aur wife hogi ya gf to uska nai sune kya?'),
#  ('Mera nai suna kyu phir', 'To breakup ho gaya'),
#  ('To breakup ho gaya', 'Galti se seekh re'),
#  ('SUNA KYU NAI', 'Kam to kiye'),
#  ('Kam to kiye', 'Band kyo kare'),
#  ('Band kyo kare', 'Dost ka group tha'),
#  ('Aisa laat maarenge ki naali me girega', '😒'),
#  ('Dhadaaaam se', 'Ok'),
#  ('Accha Google call me aisa hota h ki usme jisse baat karta h wo upar aate jata h?',
#   'Matlab'),
#  ('Matlab', 'Google call?'),
#  ('JOBHI', 'Jo latest baat hua wo upar rahega'),
#  ('Apna dikhao', 'Time ke hisab se'),
#  ('Call log dikhao', 'Kisse zayada hua usse matlab nai'),
#  ('Kisse zayada hua usse matlab nai', 'Ok'),
#  ('Ok', '<Media omitted>'),
#  ('Agar jo insaan se kl aue aaj dono baat kiya', 'Kya'),
#  ('Kya', 'Ruko kya bol gyi samajhne do'),
#  ('Hatao', 'Oh'),
#  ('Oh', 'Ha'),
#  ('Isha ko kyu kiya tha', 'Lekin kholne pe dikhayega'),
#  ('Lekin kholne pe dikhayega', 'Baahar the tab kiye the'),
#  ('Kyu', 'Ek restaurant khoj re the'),
#  ('Ek restaurant khoj re the', 'Nai mil ra tha'),
#  ('Nai mil ra tha', 'To dono alag alag jaake khoj re the'),
#  ('To dono alag alag jaake khoj re the',
#   'Nai Mila to call karke bataye idhar nai hai'),
#  ('Aisa arrange nai kar sakte ki time saath bataye uss din ki kisko call kiyebh',
#   '🙄'),
#  ('Jaise yaha time nai h', 'Hai time'),
#  ('Hai time', 'Sabse Sat likha hai coz new day hai'),
#  ('Kholne pe na', 'Nai'),
#  ('Nai', 'Agar 12 baje se pehle kholte to yahin pe time rehta'),
#  ('Agar 12 baje se pehle kholte to yahin pe time rehta', 'Last call ka'),
#  ('Lekin ab nai dikhayega?', 'Nai'),
#  ('Nai', 'Ab bas kholne pe'),
#  ('Hmko abhi bagal me chahiye na Magar',
#   'Jaise mummy ka bheje the, ek ko kholenge to uska past calls dikhayega'),
#  ('Boka Google', 'Kyo?'),
#  ('Kyo?', 'Aaj ka call?'),
#  ('Tera nau', 'Are puch re'),
#  ('Are puch re', 'Aaj ka call ka'),
#  ('Aaj ka call ka', 'Kisi ka bhi'),
#  ('Kya', 'Kya karna hai exactly bata'),
#  ('Kya karna hai exactly bata', 'Kr denge'),
#  ('Karna kuch nai h', 'Kyo?'),
#  ('Kyo?', 'Khol ke dekh lo'),
#  ('Mehnat h na bhai', 'Apna hi dekhna hai na?'),
#  ('Nope', 'To?'),
#  ('Mere loving boyfriend ka', 'Oh'),
#  ('Oh', 'To WhatsApp pe screen share krke dikhane bol do'),
#  ('To WhatsApp pe screen share krke dikhane bol do',
#   'Bf hai aur itna Shak krti hai hawwww'),
#  ('Yahi soche h', 'Aur ab Tak delete nai kr diya hoga?'),
#  ('Hogaya?', 'Ha'),
#  ('Usko pata hoga hm dekhne maangenge?', 'Accha nai batayi hai'),
#  ('Accha nai batayi hai', 'Tab ok'),
#  ('BAAAAT KAHA HORA', 'Ab mereko nai pata'),
#  ('Kya', 'Ki matter kya hai'),
#  ('Kon matter',
#   'Kya pata soch liya ho ye ek evidence ho sakta hai to ura Diya ho'),
#  ('Kya pata soch liya ho ye ek evidence ho sakta hai to ura Diya ho',
#   'TM dono ke beech'),
#  ('TM dono ke beech', 'Kyo nai hora baat'),
#  ('To ab baitha h', 'To call kyo dekhna hai'),
#  ('Kuch milta h to batayenge', 'Ok'),
#  ('Jare ab', 'Okay'),
#  ('Ab reels dekhna h', 'Nahi'),
#  ('Tum soyega?', 'Hum to GOT dekh re na😂'),
#  ('Bhak to', 'Kya'),
#  ('Kya', 'Soyegi tab jao'),
#  ('BYE', 'Reels dekhne nai'),
#  ('Reels dekhne nai', 'No'),
#  ('BYE', 'But how will you?'),
#  ('But how will you?', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', 'Hi'),
#  ('Nahi bye', 'I can'),
#  ('I can', 'No'),
#  ('Kya you can', "I don't accept your bye"),
#  ("I don't accept your bye", 'Fuck my asshole😂'),
#  ('Muh pe phenk ke jare hm', 'Lelo wapas'),
#  ('No', 'Oh sorry'),
#  ('Oh sorry', 'I mean your'),
#  ('I mean your', 'Ha'),
#  ('EW', 'Exactly'),
#  ('Hahahah', 'Itna possible nai'),
#  ('Itna possible nai', 'Dusare ka kr sakte hai'),
#  ('Dusare ka kr sakte hai', 'Aur 1.5 ep bacha'),
#  ('Aur 1.5 ep bacha', 'Fir soo jayenge hum bhi'),
#  ('Dekho jao', 'Dekh to rahe hi hai'),
#  ('Dekh to rahe hi hai', 'Ab batao'),
#  ('Ab batao', 'Attention bata hua hai?'),
#  ('Bye', 'Tabse baat kr re'),
#  ('Hm jare gaana sunne', 'Kya ok'),
#  ('Bye', '🌞'),
#  ('🌞', 'Suno'),
#  ('Suno', 'Jana kaha hai'),
#  ('Jana kaha hai', 'Laga lo gaana'),
#  ('Kl baat karte', 'Abhi na jao chor kar'),
#  ('Aww', 'Ke dil abhi bhara nahi'),
#  ('Jaake got dekho jhutha', 'Kya'),
#  ('50 jagah dhyaan laga rakha h', 'Are wo to chal hi ra'),
#  ('Are wo to chal hi ra', 'Are'),
#  ('Are', 'Tmko late reply kr re hai kya?'),
#  ('Nai', 'Then'),
#  ('Then', 'Wo gaana kaise nai laga accha'),
#  ('Wo gaana kaise nai laga accha', 'Hum to din bhar sun re'),
#  ('Rap jaisa tha', 'To?'),
#  ('Rap pasand nai', 'Bas isiliye?'),
#  ('Macchar kaatra', 'https://youtu.be/iNebpiTuX5s?si=YlxrIv19FQqvlV0s'),
#  ('https://youtu.be/iNebpiTuX5s?si=YlxrIv19FQqvlV0s',
#   'Ha yaha bhi aa gaya hai'),
#  ('Ha yaha bhi aa gaya hai', 'Performance video'),
#  ('Jare screen share karwane', 'Macchar call kr ra?'),
#  ('Macchar call kr ra?', 'Okayyy'),
#  ('Okayyy', 'Fir ana'),
#  ('HAT', 'Haa'),
#  ('Hm soye nai???', 'Sona'),
#  ('Hmko sona thaaa', '15 min ke liye bas'),
#  ('15 min ke liye bas', 'Ana'),
#  ('Ana', 'To soo'),
#  ('Bye', 'Reels dekhne jari thi tm'),
#  ('Mst sogaye hote', 'Sone se pehle 10 min ke liye ana'),
#  ('Sone se pehle 10 min ke liye ana', 'To sooti'),
#  ('Raat 11 baje', 'TM boli reel dekhne jari'),
#  ('TM boli reel dekhne jari', '.'),
#  ('Bye bye', 'Sone jari?'),
#  ('Sone jari?', '?'),
#  ('Class lene', 'To soo to abhi bhi nai ri itna sone ka bol ke'),
#  ('To soo to abhi bhi nai ri itna sone ka bol ke', 'To sone se pehle anaa'),
#  ('To sone se pehle anaa', 'Call kr dena'),
#  ('Late hojayega phir aur sone me', 'Are to soo to abhi bhi nai ro'),
#  ('Are to soo to abhi bhi nai ro', '*ri'),
#  ('*ri', 'Hum to bole padhna hai to jao, Sona hai to jao'),
#  ('To aur late kyu karenge',
#   'TM reel dekhne, gaana sunne ya class lene jari thi'),
#  ('TM reel dekhne, gaana sunne ya class lene jari thi',
#   'Sone to Jaa hi nai ri thi isiliye nai Jane diye'),
#  ('Sone to Jaa hi nai ri thi isiliye nai Jane diye',
#   'Ab sone se pehle 10 min ana'),
#  ('Ab sone se pehle 10 min ana', 'Pakka 10 min'),
#  ('Tereko janna h kya hua', 'Nahi hoga'),
#  ('Kl bata denge', 'Okay'),
#  ('Okay', 'Good night'),
#  ('Good night', 'Ho gaya?'),
#  ('Are wo dusra batane lag gaya', 'Ab nai sona hai?'),
#  ('Hai', 'Ho gaya?'),
#  ('Ho gaya?', 'Good night'),
#  ('Good night', 'Oye'),
#  ('Oye', 'Nai soyi hai to ana'),
#  ('Ha', 'Ho Gaya baat?'),
#  ('Bula kisliye raha', 'Ease hi'),
#  ('Ghanta baat hua', 'Means Gaya wo?'),
#  ('Hm soye nai tab? Raatbhar yahi karte h', 'Nai'),
#  ('Nai', '3 baje chal jana'),
#  ('3 baje chal jana', '?'),
#  ('Abhi block kar diye to call kar ra', 'Hamesha kuch rr kaise rehta hai'),
#  ('Jab kaand karta h', 'Nice <This message was edited>'),
#  ('Roz late kara deta h', 'Ya Daya aa jaye'),
#  ('Ya Daya aa jaye', 'Are 9 min bas ab'),
#  ('Chup na', 'Kiya'),
#  ('Aur mat kar', 'Ha isiliye'),
#  ('Legit alag', 'Okay'),
#  ('Okay', 'Ab gadhera ka bhi baat sun lo'),
#  ('Bolo',
#   'Zayada mat soch, kuch nai hoga....Jo karna hoga krna uske saath, lekin jab seriously nai leri itna to itna socho bhi mat'),
#  ('Wtf', 'Hamesha krta hai, ab bhi kr ra'),
#  ('Hamesha krta hai, ab bhi kr ra', 'You deleted this message'),
#  ('You deleted this message', 'Theek hai na?'),
#  ('Jab bhejna h bhejo hmse kya puchra', 'Are'),
#  ('Are', 'Tm'),
#  ('Nai', 'Kyo'),
#  ('Idk', 'Kya soch ke theek nai hai?'),
#  ('Kuch nai', 'To gaana suno ek aur soo jao'),
#  ('Sone jare seedha', 'Yehi sun lo'),
#  ('Yehi sun lo', '4 min ka gaana'),
#  ('Hmko', 'Khatam hote saath soo jana'),
#  ('Ekdum', 'Are kyooo'),
#  ('Are kyooo', '10 min me itna manage kr re'),
#  ('10 min me itna manage kr re', 'Kr lo'),
#  ('Kr lo', 'Please'),
#  ('Please', 'Rok lete lete 3 baje Tak ka bole hai, kl karenge baat'),
#  ('Rok lete lete 3 baje Tak ka bole hai, kl karenge baat', 'Soojao'),
#  ('Soojao', 'Sun ke'),
#  ('Hmko accha nai lagra', 'Sorry'),
#  ('Sorry', 'Sorry'),
#  ('Sorry', 'Abse nai ayenge raat me'),
#  ('Abse nai ayenge raat me', 'Padhna'),
#  ('Padhna', 'Jab free time mile tm msg kr dena'),
#  ('Gadha usko bole', 'Ik'),
#  ('Ik', 'Lekin time hum bhi lere na'),
#  ('Lekin time hum bhi lere na', 'Kl uth Jana'),
#  ('Kl uth Jana', 'Din me soo Jana fir'),
#  ('KAHTUM KAISE NAI HOTAAA????', 'Subah lekin uth jana'),
#  ('Chal sone', 'Chalo'),
#  ('Chalo', 'Uthana hai?'),
#  ('Tumko khud utha jata nai', 'Are ab hum jaga ke rakhe to utha bhi denge'),
#  ('Are ab hum jaga ke rakhe to utha bhi denge',
#   'Tumko uthane ke liye uth jayenge'),
#  ('Tumse utha jata h khud?', 'Nai'),
#  ("Let's see", 'Time?'),
#  ('8.45', 'Ok'),
#  ('Bye', 'Bye bahut bolti hai ab tm'),
#  ('Bye bahut bolti hai ab tm', 'Good night'),
#  ('Good night', 'Usse mereko kya'),
#  ('Usse mereko kya', 'Apna bata de'),
#  ('Apna bata de', '*re'),
#  ('Aadat hogaya wahise', 'Sudharo'),
#  ('Sudharo', 'Sooja'),
#  ('Sooja', 'Neend hi nai ata hai ab jaldi'),
#  ('Neend hi nai ata hai ab jaldi', 'Aaj jaag lere, nashta karke soyenge'),
#  ('Aaj jaag lere, nashta karke soyenge', 'Thoda sa'),
#  ('Thoda sa', 'Taaki kl raat neend aye'),
#  ('Bura nai h tum utna bhi', '🙄'),
#  ('10 me 9 bura h', 'Soyi nai?'),
#  ('2 accha', 'Maths kamzor ho Gaya hai raat me?'),
#  ('Maths kamzor ho Gaya hai raat me?', '10-9=2?'),
#  ('8 and 2', 'Aansu kyo'),
#  ('Aansu kyo', 'Ok'),
#  ('Ek selfie milega?', 'Kiya'),
#  ('Kiya', 'Kyo'),
#  ('Lao', 'You deleted this message'),
#  ('Such a good boy', 'Ruko'),
#  ('<Media omitted>', '<Media omitted>'),
#  ('<Media omitted>', 'U too'),
#  ('Chain nai?', 'Nai'),
#  ('Bhai hm roye j', 'Kyo'),
#  ('Kl de denge', 'Chor soo tm'),
#  ('Chor soo tm', 'Call?'),
#  ('Tera forehead kitna saaf and khali h', 'Pimple hai beech me'),
#  ('Chalega', 'Itna jaldi?'),
#  ('Itna jaldi?', 'Bf hote hue easa bol ri, shame shame'),
#  ('Bf hote hue easa bol ri, shame shame', 'Are shame wala scene dikhana tha😂'),
#  ('Are shame wala scene dikhana tha😂', 'Jo bole ek aur scene aya'),
#  ('Jo bole ek aur scene aya', 'Ya apne search kr lena, Cersie walk of shame'),
#  ('Isha pasand h?', 'YouTube pe nai mil ra, koi porn website pe hi milega'),
#  ('YouTube pe nai mil ra, koi porn website pe hi milega', '🤦🏻\u200d♂'),
#  ('🤦🏻\u200d♂', 'Nahi'),
#  ('Nahi', 'Aur abhi kyo yaad aaraa????'),
#  ('Aur abhi kyo yaad aaraa????', 'Abhi to naam bhi nai liye'),
#  ('Shakal dekhe to yaad aya ki yahi leke pizza khane Gaya tha', 'Oooh'),
#  ('Oooh', 'Sorry apna shakal change nai kiye'),
#  ('Karn', 'Kya'),
#  ('Kya', 'Nope'),
#  ('?', 'Bolo'),
#  ('?', 'Ans Mera'),
#  ('Ans Mera', 'Ab question pucho 😂'),
#  ('😂', 'Idk'),
#  ('Idk', 'Bolo jo bhi bol ri'),
#  ('Haww', 'Nahi😓'),
#  ('Nahi😓', 'Mereko Jadoo pasand hai'),
#  ('Tumko kya laga hm kya puchenge', 'Idk'),
#  ('Idk', 'Bas Karn se start krti hai to kuch hota hai'),
#  ('Bas Karn se start krti hai to kuch hota hai', 'Bolo'),
#  ('Kya', 'Jo bhi bolna tha <This message was edited>'),
#  ('Kuch laga to kya', 'Will you marry me laga mereko'),
#  ('Will you marry me laga mereko', 'So no'),
#  ('Why', 'Mereko apna shadi me bhi khana hai Tera me bhi'),
#  ('Mereko apna shadi me bhi khana hai Tera me bhi', '2 party rahega'),
#  ('2 party rahega', '2 baar chicken torenge'),
#  ('2 baar chicken torenge', 'Kya pata nai'),
#  ('Kya pata nai', 'Jo bol ri thi bolo'),
#  ('Chalo sone', 'Are blo'),
#  ('Are blo', 'Bolo'),
#  ('Tum fuddu jaisa baat karke mera dimag ka faluda kar deta', '🙄'),
#  ('🙄', 'Bolo ab'),
#  ('Bolo ab', 'Serious hai'),
#  ('Pata nai', 'Bolo sab'),
#  ('To leliye', 'Bas Karn bolna tha?'),
#  ('Bas Karn bolna tha?', '??'),
#  ('Tumhara dimag theek nai', 'Are bolo na ab'),
#  ('Are bolo na ab', 'Kya 3 4 baat'),
#  ('Hm bhool gaye', 'Yaad karo'),
#  ('Hm legit bhool gaye', 'Okay'),
#  ('Tum aadmi theek nai', '🙄'),
#  ('Thoda theek h', 'Ok'),
#  ('Dost h tum mera?', '2/10 na'),
#  ('2/10 na', 'Haa'),
#  ('Good boy banjao', 'Kyo'),
#  ('Accha dost rakhenge', '??'),
#  ('??', 'Tera?'),
#  ('Tera?',
#   'Fir tm pat jayegi na... isiliye nai ban re <This message was edited>'),
#  ('Mereko patana mushkil he nai namumkin h', 'Oooo'),
#  ('Tum accha ladka jaisa raho', 'Kyo'),
#  ('Kyo', 'Iske liye?'),
#  ('Ha', 'Hai to abhi bhi'),
#  ('Abhi man karta h jaise gaali deke 4 laat maarke bhaga de', '😎'),
#  ('Kya dikkat', 'Hum to waise hi hai'),
#  ('Dinbhar nai hota', 'Ease hi to hote hai'),
#  ('Aye Holika h aaj', 'Ha'),
#  ('Hm aak he hue the', 'Nahi'),
#  ('Holi kab mana ra tumlog', '28 ko'),
#  ('28 ko', 'Kl'),
#  ('Are wtf', '28'),
#  ('25 ya 26', '25'),
#  ('26', 'Hostel me 25'),
#  ('Isha saath khelega phir?', 'Ha rahegi wo bhi'),
#  ('Pasand h na',
#   'Gulal and colours ke liye bare minimum Rs 30 Contri chahiye from all.'),
#  ('Gulal and colours ke liye bare minimum Rs 30 Contri chahiye from all.',
#   'Mere hi saath kyo rahegi'),
#  ('Mere hi saath kyo rahegi', 'Nahi'),
#  ('Mat lagana colour', 'Bata ri?'),
#  ('Bata ri?', 'Why'),
#  ('Ha', 'Ok'),
#  ('Hai tum maana?', 'Bata ri to maan lere😂😂'),
#  ('Ok', 'TM puch thodi ri'),
#  ('TM puch thodi ri', 'Bata ri hai na'),
#  ('Bata ri hai na', 'To kya kare'),
#  ('Ok', 'Kya ok?'),
#  ('Kya ok?', 'Ab sone chale?'),
#  ('Sone jare', 'Oooo'),
#  ('Oooo', 'Ye to ekdum unexpected tha'),
#  ('Ye to ekdum unexpected tha', 'Are Mera recharge khatam ho gaya hai'),
#  ('Are Mera recharge khatam ho gaya hai', 'Call/sms nai kr sakte'),
#  ('Call/sms nai kr sakte', 'Nahi hai pasand!!!'),
#  ('Nahi hai pasand!!!', 'Kitna baar bole'),
#  ('Kitna baar bole',
#   'Larki acchi hai, acchi dost hai.....ye Yash wala ke chalte friend group Tut Gaya ya tuta nai to bhi pehle jaisa nai rahega isliye bura lagta hai, ab nai utna'),
#  ('Larki acchi hai, acchi dost hai.....ye Yash wala ke chalte friend group Tut Gaya ya tuta nai to bhi pehle jaisa nai rahega isliye bura lagta hai, ab nai utna',
#   'Are yaar'),
#  ('Are yaar', 'Hum uthayenge kaisew'),
#  ('Hum uthayenge kaisew', 'Net off kr li'),
#  ('Net off kr li', 'Recharge kr liye fir bhi nai lag ra call'),
#  ('Recharge kr liye fir bhi nai lag ra call', 'Good morning'),
#  ('Wau', '🙄'),
#  ('Ruchi didi call kardi 5 min pehle', 'Oh'),
#  ('Sogaya re', 'Nahi'),
#  ('Recharge karke uthaya😭😭', 'Kyo?'),
#  ('Baapre', '🙄'),
#  ('🙄', 'Idli khane aa gye'),
#  ('null', 'Uthaye hai pehle bhi'),
#  ('Uthaye hai pehle bhi', 'Ha ig?'),
#  ('Ha?', 'Ha'),
#  ('Usise karna baat ab', 'Are'),
#  ('Hum kya h', 'Hat'),
#  ('Hat', 'Bestie'),
#  ('Bestie', '😂'),
#  ('HUM KYA H', 'Nahi'),
#  ('Nahi', 'Bole to'),
#  ('Bole to', 'Bestie'),
#  ('null', '🙄'),
#  ('🙄', 'Ok nai hui'),
#  ('Kl bola pasand h', 'Nahi hai'),
#  ('KYA KAR RA TYM', 'Ye to tm batayi'),
#  ('Tum maana', 'TM puchti tab na batate'),
#  ('Hm chaanta maarke chal jayenge', 'Kya?'),
#  ('Kya?', 'Kaise?'),
#  ('Kaise?', 'Are nahi krte haii'),
#  ('To achhi dost kaise ye batao ab', 'Ok nahi hai'),
#  ('Are aise modify ab thodi karo', 'To?'),
#  ('Kya h wo', 'Nahi krte hai kuch share'),
#  ('Wo close dost h?', 'Nahi'),
#  ('Nahi', 'Are dost hai'),
#  ('Are dost hai', 'Bas'),
#  ('Tum idli khao', 'Ok?'),
#  ('Ok?', 'Kha liye plate rakhne gye the'),
#  ('Kha liye plate rakhne gye the', 'And coffee lene'),
#  ('Tumhare man se to acchi dost nikla', 'Accha dost kya hota hai?'),
#  ('Accha dost kya hota hai?', 'Yash hai accha dost'),
#  ('Yash hai accha dost', 'Ab sab share thodi krte hai kisi se'),
#  ('Close dost jisse sab share karo', 'Comparatively'),
#  ('Comparatively', 'Acchi'),
#  ('Lo', 'Comparatively acchi'),
#  ('Hm kya h', 'Means ladki me college me sabse acchi wahi hogi'),
#  ('Means ladki me college me sabse acchi wahi hogi', 'Bestie'),
#  ('Seriously bolo na', 'Bol to ree'),
#  ('Bol to ree', 'TM meri bestie and hum tumhare besta'),
#  ('Ok', 'Holi khel ra'),
#  ('Holi khel ra', '<Media omitted>'),
#  ('<Media omitted>', '<Media omitted>'),
#  ('Nice', '<Media omitted>'),
#  ('<Media omitted>', '<Media omitted>'),
#  ('<Media omitted>', '<Media omitted>'),
#  ('<Media omitted>', '<Media omitted>'),
#  ('<Media omitted>', '<Media omitted>'),
#  ('Tumko bhaang kon pila Diya', '🤷🏻\u200d♂️'),
#  ('🤷🏻\u200d♂️', '<Media omitted>'),
#  ('Hmko dikhana h kuch', 'Ga'),
#  ('Ga', 'Ha'),
#  ('Sora tha?', 'Ha'),
#  ('To', 'To'),
#  ('To', '<Media omitted>'),
#  ('<Media omitted>', 'Koi Naya trend hai kya multiple husband ka?'),
#  ('Koi Naya trend hai kya multiple husband ka?', 'Isko Islam nai bolte?'),
#  ('Ye dress liye', 'Awww'),
#  ('Awww', 'Cute lag ri'),
#  ('Cute lag ri', 'Ha'),
#  ('Ha', 'Isme bhi'),
#  ('Aur ek lamba sa frock suit jaisa', 'Nice'),
#  ('NAHI LIYE YE SUAR😭😭😭😭😭😭😭', 'Kiska phone hai?'),
#  ('Bhai', '13?'),
#  ('Mera bday paar hojayega', 'Ha 13 hi lag ra'),
#  ('Ha 13 hi lag ra', '?'),
#  ('Photos aajayega', 'Oh'),
#  ('Choti li ek gol sa', 'Accha hai'),
#  ('Accha hai', 'Jo pehni hai wo bhi accha hai'),
#  ('Jo pehni hai wo bhi accha hai', 'Ha'),
#  ('Ha', 'Le leti'),
#  ('Lekin', 'Oh'),
#  ('Dress pyaara h na', 'Haa'),
#  ('Same colour me ek full length ka suit liye',
#   'Mereko koi college fest me tere saath jane ka man kr ra'),
#  ('Mereko koi college fest me tere saath jane ka man kr ra',
#   'Not possible but🙄'),
#  ('Hm soch he re the ki koi aisa pink me nai h merepaas', 'Oh'),
#  ('Hm ye dress pehen sakte the', 'Jo man pehen sakti hai'),
#  ('Jo man pehen sakti hai',
#   'Padh accha se abhi bas, college me ho jayega fir jana'),
#  ('Fest nai tobhi koi singer ka me zarur chalenge ek baar', 'Maza ata hai'),
#  ('Maza ata hai', 'Kaha se'),
#  ('Kyu', 'Singer Ghar pe ayega?'),
#  ('Nai', 'Fest me hi na ayega'),
#  ('Fest me hi na ayega', 'Aditya Rikhari bhi aara koi college me'),
#  ('Oh ha', 'Dekhe nai kisme'),
#  ('?', 'Aur apna concerts me'),
#  ('Bina college ka baccha sabko jana hua to', 'But isme Paisa lagta hai'),
#  ('But isme Paisa lagta hai', 'Fest me to free rehta hai'),
#  ('Fest me to free rehta hai', 'Nai ghus sakti'),
#  ('Nai ghus sakti', 'Id card lagta hai'),
#  ('Id card lagta hai', 'Ya jugar se ghuso'),
#  ('To yelog ke liye kuch hota hoga na', 'Source laga ke/ Diwal chadh ke'),
#  ('Source laga ke/ Diwal chadh ke',
#   'Rules ke hisab se college fest me bas Students aa sakta hai'),
#  ('Rules ke hisab se college fest me bas Students aa sakta hai',
#   'Concert me jao jiska Jana hai'),
#  ('Concert me jao jiska Jana hai', 'But Paisa lagta hai'),
#  ('But Paisa lagta hai', 'College fest is better but'),
#  ('College fest is better but', 'Yaha to bas gaana suno bheer me'),
#  ('Yaha to bas gaana suno bheer me',
#   'College me bahut kuch rehta hai + raat me concert'),
#  ('College me bahut kuch rehta hai + raat me concert',
#   'Sunna hai bheer me suno, nai sunna to bheer se peeche ho jao'),
#  ('Reels me dekhe h', 'Is baar nai gye hum'),
#  ('Is baar nai gye hum', '3rd year me'),
#  ('3rd year me', 'NSUT ka is baar ka batate the na?'),
#  ('Hmko kyu batayega', 'Sunidhi Chauhan, Raftaar aur King Aya tha'),
#  ('?', 'Nai gye'),
#  ('Kyu', 'CUET'),
#  ('<Media omitted>',
#   'Din me quiz me gye the, jis din quiz tha us din King ka tha.....Raftaar ka hota to ruk bhi jate'),
#  ('Din me quiz me gye the, jis din quiz tha us din King ka tha.....Raftaar ka hota to ruk bhi jate',
#   'Jala denge sab'),
#  ('Aur lenge', 'Mera to 1 hi khatam nai hora'),
#  ('Suar bhi pyaara tha na 😭', 'null'),
#  ('Akele chod diye usko', 'Ayush Bisht aake soo gaya'),
#  ('Ro ra hoga', '🙄'),
#  ('Are wo list kiska tha', 'Yash kahin baahar gaya'),
#  ('Yash kahin baahar gaya', 'Mere college ki koi ladki ka'),
#  ('Mere college ki koi ladki ka', 'Anti social bhi chahiye'),
#  ('Anti social bhi chahiye', 'Aur uska dost se baat bhi kare accha se'),
#  ('Aur uska dost se baat bhi kare accha se',
#   'Means apna dost na ho uska lekin uski dost se baat kare accha se'),
#  ('Only inse', 'Ha, pata le usi ki dost me kisi ko fir'),
#  ('Hm photo dikhane ko uthaye the', 'Kiya'),
#  ('Kiya', 'Ab to uth gye'),
#  ('Ab to uth gye', 'Aaj subah uthe aur soye nai'),
#  ('Aaj subah uthe aur soye nai',
#   'Aaj shayad raat me neend aa jaye <This message was edited>'),
#  ('Mera bhi raat kha jata', 'Mera sab reels dekh li?'),
#  ('Mera sab reels dekh li?', '🙄'),
#  ('Abhi koi nai dekhe h', 'Abhi nai'),
#  ('ABHI TO AAYE HE', 'Kl ka hi'),
#  ('Ha sab dekhe', 'Non veg walaaa'),
#  ('Non veg walaaa', 'Chicken Zinger Pro mast hai'),
#  ('Chicken Zinger Pro mast hai', 'Uska tareef Kiya hoga'),
#  ('Uska tareef Kiya hoga', 'Veg to normal sa hi hai'),
#  ('Sab dekhe', 'Ok'),
#  ('Aankh h na?', 'Dekhe the'),
#  ('Mera bhai veg khata h', 'null'),
#  ('Kya', 'Na veg zinger to normal hai'),
#  ('Na veg zinger to normal hai', 'KFC me veg kyo khana'),
#  ('Merese ek mota nai sambhal ra abhi', 'Ye mota nai hai'),
#  ('To pata lo', 'Tumhara baat Kara de?'),
#  ('Tumhara baat Kara de?', 'Jaanta to hai hi tmko'),
#  ('How', 'Merese'),
#  ('Merese', '🤷🏻\u200d♂️'),
#  ('🤷🏻\u200d♂️', 'Dusari, teesri, chauthi....gin kon ra ab'),
#  ('Ja marja', 'Kaha pe'),
#  ('Kaha pe', 'I mean'),
#  ('I mean', 'Kispe'),
#  ('Kispe', '??'),
#  ('??', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('.', '.'),
#  ('Yahase', 'Kyooo'),
#  ('Nai?', 'Dal do'),
#  ('Dal do', 'As u wish'),
#  ('Tum bhad me jao', 'Kya'),
#  ('Kya', 'Dal do'),
#  ('Dal do', 'Accha to hai'),
#  ('BUT YE SOCHE THE HM???', 'Pink hai na'),
#  ('ANTAR DEKHO', 'Pink to pink hota hai, hot ho ya rose'),
#  ('To kya pink dikhake green nikal jata',
#   'Ye to camera ka difference bhi hai'),
#  ('Mera aankh andha h?', 'Ok didi'),
#  ('Ok didi', 'Puch ri?'),
#  ('Ye exact colour h wo dress ka', 'Okay'),
#  ('Bakchodi karta tum', 'To?'),
#  ('To?', 'Kya dikkat hai'),
#  ('Kya dikkat hai', 'Bakchodi is fun'),
#  ('To niklo', 'Notification se reply mat karo'),
#  ('Notification se reply mat karo', 'Idhar aao'),
#  ('Nai', '<Media omitted>'),
#  ('Ho sakta h', 'Are Aaj ek online quiz hai 7 baje'),
#  ('Are Aaj ek online quiz hai 7 baje', '<Media omitted>'),
#  ('PHOTO DAALE YA NAI', 'Daal do'),
#  ('Daal do', 'To Ramphal Chowk pe ye Dale hum'),
#  ('To', 'Team name suggest kr'),
#  ('Team name suggest kr', 'Ek aur team gensex hai'),
#  ('Ek aur team gensex hai', 'Ek creampies'),
#  ('Mereko nai maalum bhai ganda ganda naam', 'Ye bahut accha naam laga'),
#  ('Pom pom rakhdo 😂', 'Okay'),
#  ('Kyu', 'Ex&exex?'),
#  ('Ex&exex?', 'Ye use kr chuke hai hum aur Yash ek quiz me'),
#  ('Rakhdo', 'Okay'),
#  ('Okay', 'Dekhte hai'),
#  ('Bolta h wolog naam ?', 'Ha'),
#  ('Chi', 'XNXX'),
#  ('XNXX', 'Aur kaise'),
#  ('Niklo yahase', 'Why'),
#  ('Photo daale ya nai', 'Pom pom bhi accha hai'),
#  ('Kyunki BOLRE hk', "Let's see"),
#  ("Let's see", 'To kya hua'),
#  ('ANNOYING HAI TUM', 'Tm to bahut kuch bolti hai'),
#  ('Tm to bahut kuch bolti hai', '🤷🏻\u200d♂️'),
#  ...]

# %%
from transformers import GPT2Tokenizer
import torch
from torch.utils.data import Dataset

# Step 1: Initialize the tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token  # Set the pad token to EOS

# Step 2: Prepare Dataset
class ChatDataset(Dataset):
    def __init__(self, conversation_pairs, tokenizer, max_length=512):
        self.input_ids = []
        self.attention_masks = []
        
        for input_text, output_text in conversation_pairs:
            # Combine input and output with a separator
            prompt = f"User: {input_text} Bot: {output_text}"
            encodings_dict = tokenizer(prompt, truncation=True, max_length=max_length, padding="max_length")
            
            self.input_ids.append(encodings_dict['input_ids'])
            self.attention_masks.append(encodings_dict['attention_mask'])
    
    def __len__(self):
        return len(self.input_ids)
    
    def __getitem__(self, idx):
        return {
            'input_ids': torch.tensor(self.input_ids[idx]),
            'attention_mask': torch.tensor(self.attention_masks[idx]),
            'labels': torch.tensor(self.input_ids[idx])  # Labels are the same as input_ids for causal LM
        }
    
dataset = ChatDataset(conversation_pairs, tokenizer)

# %%
from transformers import GPT2LMHeadModel, Trainer, TrainingArguments

# Load the Pretrained GPT-2 Model
model = GPT2LMHeadModel.from_pretrained("gpt2")
model.resize_token_embeddings(len(tokenizer))

# Define Training Arguments
training_args = TrainingArguments(
    output_dir="./results",
    overwrite_output_dir=True,
    num_train_epochs=3,
    per_device_train_batch_size=4,
    save_steps=500,
    save_total_limit=2,
    logging_dir="./logs",
    logging_steps=100,
    learning_rate=5e-5,
    weight_decay=0.01,
    fp16=True,  # Mixed precision training if supported
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
    tokenizer=tokenizer,
)

# Train the Model
trainer.train()

# Save the Model and Tokenizer
trainer.save_model("./chatbot_model")
tokenizer.save_pretrained("./chatbot_model")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/transformers/activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# File ~/.local/lib/python3.12/site-packages/tf_keras/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras import __internal__
#       4 from tf_keras import activations
#
# File ~/.local/lib/python3.12/site-packages/tf_keras/__internal__/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras.__internal__ import backend
#       4 from tf_keras.__internal__ import layers
#
# File ~/.local/lib/python3.12/site-packages/tf_keras/__internal__/backend/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras.src.backend import _initialize_variables as initialize_variables
#       4 from tf_keras.src.backend import track_variable
#
# File ~/.local/lib/python3.12/site-packages/tf_keras/src/__init__.py:21
#      15 """Implementation of the TF-Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
# ---> 21 from tf_keras.src import applications
#      22 from tf_keras.src import distribute
#
# File ~/.local/lib/python3.12/site-packages/tf_keras/src/applications/__init__.py:18
#      15 """Keras Applications are premade architectures with pre-trained weights."""
# ---> 18 from tf_keras.src.applications.convnext import ConvNeXtBase
#      19 from tf_keras.src.applications.convnext import ConvNeXtLarge
#
# File ~/.local/lib/python3.12/site-packages/tf_keras/src/applications/convnext.py:26
#      25 import numpy as np
# ---> 26 import tensorflow.compat.v2 as tf
#      28 from tf_keras.src import backend
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/_api/v2/compat/v2/__init__.py:85
#      84 from tensorflow.python.ops.gen_data_flow_ops import dynamic_stitch # line: 736
# ---> 85 from tensorflow.python.ops.gen_experimental_dataset_ops import check_pinned # line: 701
#      86 from tensorflow.python.ops.gen_linalg_ops import matrix_square_root # line: 1913
#
# ImportError: cannot import name 'check_pinned' from 'tensorflow.python.ops.gen_experimental_dataset_ops' (/home/ayushkarn/.local/lib/python3.12/site-packages/tensorflow/python/ops/gen_experimental_dataset_ops.py)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/transformers/utils/import_utils.py:1793, in _LazyModule._get_module(self, module_name)
#    1792 try:
# -> 1793     return importlib.import_module("." + module_name, self.__name__)
#    1794 except Exception as e:
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.local/lib/python3.12/site-packages/transformers/modeling_tf_utils.py:38
#      37 from . import DataCollatorWithPadding, DefaultDataCollator
# ---> 38 from .activations_tf import get_tf_activation
#      39 from .configuration_utils import PretrainedConfig
#
# File ~/.local/lib/python3.12/site-packages/transformers/activations_tf.py:27
#      26     if parse(keras.__version__).major > 2:
# ---> 27         raise ValueError(
#      28             "Your currently installed version of Keras is Keras 3, but this is not yet supported in "
#      29             "Transformers. Please install the backwards-compatible tf-keras package with "
#      30             "`pip install tf-keras`."
#      31         )
#      34 def _gelu(x):
#
# ValueError: Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/transformers/utils/import_utils.py:1793, in _LazyModule._get_module(self, module_name)
#    1792 try:
# -> 1793     return importlib.import_module("." + module_name, self.__name__)
#    1794 except Exception as e:
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.local/lib/python3.12/site-packages/transformers/integrations/integration_utils.py:36
#      34 import packaging.version
# ---> 36 from .. import PreTrainedModel, TFPreTrainedModel
#      37 from .. import __version__ as version
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/.local/lib/python3.12/site-packages/transformers/utils/import_utils.py:1781, in _LazyModule.__getattr__(self, name)
#    1780 elif name in self._class_to_module.keys():
# -> 1781     module = self._get_module(self._class_to_module[name])
#    1782     value = getattr(module, name)
#
# File ~/.local/lib/python3.12/site-packages/transformers/utils/import_utils.py:1795, in _LazyModule._get_module(self, module_name)
#    1794 except Exception as e:
# -> 1795     raise RuntimeError(
#    1796         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1797         f" traceback):\n{e}"
#    1798     ) from e
#
# RuntimeError: Failed to import transformers.modeling_tf_utils because of the following error (look up to see its traceback):
# Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/transformers/utils/import_utils.py:1793, in _LazyModule._get_module(self, module_name)
#    1792 try:
# -> 1793     return importlib.import_module("." + module_name, self.__name__)
#    1794 except Exception as e:
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.local/lib/python3.12/site-packages/transformers/trainer.py:42
#      40 # Integrations must be imported before ML frameworks:
#      41 # isort: off
# ---> 42 from .integrations import (
#      43     get_reporting_integration_callbacks,
#      44     hp_params,
#      45 )
#      47 # isort: on
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/.local/lib/python3.12/site-packages/transformers/utils/import_utils.py:1781, in _LazyModule.__getattr__(self, name)
#    1780 elif name in self._class_to_module.keys():
# -> 1781     module = self._get_module(self._class_to_module[name])
#    1782     value = getattr(module, name)
#
# File ~/.local/lib/python3.12/site-packages/transformers/utils/import_utils.py:1795, in _LazyModule._get_module(self, module_name)
#    1794 except Exception as e:
# -> 1795     raise RuntimeError(
#    1796         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1797         f" traceback):\n{e}"
#    1798     ) from e
#
# RuntimeError: Failed to import transformers.integrations.integration_utils because of the following error (look up to see its traceback):
# Failed to import transformers.modeling_tf_utils because of the following error (look up to see its traceback):
# Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 from transformers import GPT2LMHeadModel, Trainer, TrainingArguments
#       3 # Load the Pretrained GPT-2 Model
#       4 model = GPT2LMHeadModel.from_pretrained("gpt2")
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/.local/lib/python3.12/site-packages/transformers/utils/import_utils.py:1781, in _LazyModule.__getattr__(self, name)
#    1779     value = Placeholder
#    1780 elif name in self._class_to_module.keys():
# -> 1781     module = self._get_module(self._class_to_module[name])
#    1782     value = getattr(module, name)
#    1783 elif name in self._modules:
#
# File ~/.local/lib/python3.12/site-packages/transformers/utils/import_utils.py:1795, in _LazyModule._get_module(self, module_name)
#    1793     return importlib.import_module("." + module_name, self.__name__)
#    1794 except Exception as e:
# -> 1795     raise RuntimeError(
#    1796         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1797         f" traceback):\n{e}"
#    1798     ) from e
#
# RuntimeError: Failed to import transformers.trainer because of the following error (look up to see its traceback):
# Failed to import transformers.integrations.integration_utils because of the following error (look up to see its traceback):
# Failed to import transformers.modeling_tf_utils because of the following error (look up to see its traceback):
# Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
